# %%
import pyactup as pau

# %%
dm = pau.Memory()
dm.learn(a="a", b="b", c="c", d="d", e="e")
dir(dm)
# Out:
# ['_Activations',
#  '_SQRT_2',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_activation_history',
#  '_activation_noise_cache',
#  '_activation_noise_cache_time',
#  '_activations',
#  '_advance',
#  '_cite',
#  '_clear_noise_cache',
#  '_decay',
#  '_exact_match',
#  '_expt_cache',
#  '_learning_time_increment',
#  '_ln_1_mius_d',
#  '_ln_cache',
#  '_make_noise',
#  '_maximum_similarity',
#  '_minimum_similarity',
#  '_mismatch',
#  '_noise',
#  '_optimized_learning',
#  '_partial_match',
# ...
